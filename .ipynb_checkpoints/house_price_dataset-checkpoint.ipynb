# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
# %matplotlib inline

# %% [markdown]
# ## Loading the data

# %%
train_data=pd.read_csv('F:\\data_science\\house_prices_dataset\\train.csv')
test_data=pd.read_csv('F:\\data_science\\house_prices_dataset\\test.csv')
train_data.head()  #first five rows of the data
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
del train_data['Id']
del test_data['Id']

# %%
train_data.shape  #dimensions of the data
# Out:
# (1460, 80)

# %%
train_data.columns # all the features of the data
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
null_columns=train_data.columns[train_data.isnull().any()]
null_columns # columns with missing values
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
# Number of missing values in each column
print(train_data[null_columns].isnull().sum())
print('Number of missing columns: '+str(train_data[null_columns].isnull().any().sum()))
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64
# Number of missing columns: 19

# %%
train_data.dtypes # datatypes of the variables
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 80, dtype: object

# %%
#These are the variables which assume dicrete names as values.
categorical_variables=train_data.dtypes[train_data.dtypes=='object'].index.values
categorical_variables
# Out:
# array(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'], dtype=object)

# %%
# This displays the number of types of each of the categorical variables.
train_data[categorical_variables].apply(lambda x: len(x.unique()))
# Out:
# MSZoning          5
# Street            2
# Alley             3
# LotShape          4
# LandContour       4
# Utilities         2
# LotConfig         5
# LandSlope         3
# Neighborhood     25
# Condition1        9
# Condition2        8
# BldgType          5
# HouseStyle        8
# RoofStyle         6
# RoofMatl          8
# Exterior1st      15
# Exterior2nd      16
# MasVnrType        5
# ExterQual         4
# ExterCond         5
# Foundation        6
# BsmtQual          5
# BsmtCond          5
# BsmtExposure      5
# BsmtFinType1      7
# BsmtFinType2      7
# Heating           6
# HeatingQC         5
# CentralAir        2
# Electrical        6
# KitchenQual       4
# Functional        7
# FireplaceQu       6
# GarageType        7
# GarageFinish      4
# GarageQual        6
# GarageCond        6
# PavedDrive        3
# PoolQC            4
# Fence             5
# MiscFeature       5
# SaleType          9
# SaleCondition     6
# dtype: int64

# %%
for i in categorical_variables:
    if i in null_columns:
        print(i,"    ",train_data[i].isnull().sum())
# Out:
# Alley      1369
# MasVnrType      8
# BsmtQual      37
# BsmtCond      37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical      1
# FireplaceQu      690
# GarageType      81
# GarageFinish      81
# GarageQual      81
# GarageCond      81
# PoolQC      1453
# Fence      1179
# MiscFeature      1406

# %% [markdown]
# In data description, we can see that "Nan" values of categorical variables are not missing value rather it representss the absence of that particular feature in house as represented by ctegorical variable.

# %% [markdown]
# ### Encoding of variables

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# filling the Nan values with "None" for encoding of labels
train_data[categorical_variables]=train_data[categorical_variables].fillna('None')

# %%
from collections import defaultdict
d = defaultdict(LabelEncoder)

# %%
encoded_train_data=pd.DataFrame(data=train_data,copy=True)

# %%
#train_data is encoded.
encoded_train_data[categorical_variables] =encoded_train_data[categorical_variables].apply(lambda x: d[x.name].fit_transform(x))

# %%
encoded_train_data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0          60         3         65.0     8450       1      1         3
# 1          20         3         80.0     9600       1      1         3
# 2          60         3         68.0    11250       1      1         0
# 3          70         3         60.0     9550       1      1         0
# 4          60         3         84.0    14260       1      1         0
#
#    LandContour  Utilities  LotConfig    ...      PoolArea  PoolQC  Fence  \
# 0            3          0          4    ...             0       3      4
# 1            3          0          2    ...             0       3      4
# 2            3          0          4    ...             0       3      4
# 3            3          0          0    ...             0       3      4
# 4            3          0          2    ...             0       3      4
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0            1        0       2    2008         8              4     208500
# 1            1        0       5    2007         8              4     181500
# 2            1        0       9    2008         8              4     223500
# 3            1        0       2    2006         8              0     140000
# 4            1        0      12    2008         8              4     250000
#
# [5 rows x 80 columns]

# %% [markdown]
# encoded_train_data will be used for model fitting and missing value imputation.

# %% [markdown]
# ### Missing value imputation

# %% [markdown]
# There are only three variables with missing values.

# %%
# filling the 'MasVnrArea' column's missing value with zeros
train_data['MasVnrArea']=train_data['MasVnrArea'].fillna(0)
encoded_train_data['MasVnrArea']=encoded_train_data['MasVnrArea'].fillna(0)

# %% [markdown]
# Another missing values column is the 'LotFrontage'. Let's know it's distribution.

# %%
plt.hist(train_data['LotFrontage'].dropna(), alpha=0.5, color='blue');
plt.title('LotFrontage distribution');

# %% [markdown]
# I am filling the 'LotFrontage' missing values with it's mean.

# %%
mean_lotfrontage=train_data['LotFrontage'].dropna().mean()

# %%
train_data['LotFrontage']=train_data['LotFrontage'].fillna(mean_lotfrontage)
encoded_train_data['LotFrontage']=encoded_train_data['LotFrontage'].fillna(mean_lotfrontage)

# %%
#Again plotting the 'LotFrontage' variable.
plt.hist(train_data['LotFrontage'].dropna(), alpha=0.5, color='blue');
plt.title('LotFrontage distribution');

# %% [markdown]
# Now, the missing value variable left is 'GarageYrBlt'. It represents the year in which the garage was built. Now, since there is no garage, I am substituting the Nan with 0.

# %%
train_data['GarageYrBlt']=train_data['GarageYrBlt'].fillna(0)
encoded_train_data['GarageYrBlt']=encoded_train_data['GarageYrBlt'].fillna(0)

# %% [markdown]
# ## Visualizations and feature engineering

# %%
train_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  None      Reg
# 1          20       RL         80.0     9600   Pave  None      Reg
# 2          60       RL         68.0    11250   Pave  None      IR1
# 3          70       RL         60.0     9550   Pave  None      IR1
# 4          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside    ...            0   None  None
# 1         Lvl    AllPub       FR2    ...            0   None  None
# 2         Lvl    AllPub    Inside    ...            0   None  None
# 3         Lvl    AllPub    Corner    ...            0   None  None
# 4         Lvl    AllPub       FR2    ...            0   None  None
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0        None       0      2    2008        WD         Normal     208500
# 1        None       0      5    2007        WD         Normal     181500
# 2        None       0      9    2008        WD         Normal     223500
# 3        None       0      2    2006        WD        Abnorml     140000
# 4        None       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
train_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  None      Reg
# 1          20       RL         80.0     9600   Pave  None      Reg
# 2          60       RL         68.0    11250   Pave  None      IR1
# 3          70       RL         60.0     9550   Pave  None      IR1
# 4          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside    ...            0   None  None
# 1         Lvl    AllPub       FR2    ...            0   None  None
# 2         Lvl    AllPub    Inside    ...            0   None  None
# 3         Lvl    AllPub    Corner    ...            0   None  None
# 4         Lvl    AllPub       FR2    ...            0   None  None
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0        None       0      2    2008        WD         Normal     208500
# 1        None       0      5    2007        WD         Normal     181500
# 2        None       0      9    2008        WD         Normal     223500
# 3        None       0      2    2006        WD        Abnorml     140000
# 4        None       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
import seaborn as sns

# %%
#distribution of selling price.
sns.distplot(train_data['SalePrice']);
print ('average sale price: '+str(train_data['SalePrice'].mean()))
# Out:
# average sale price: 180921.19589041095

# %% [markdown]
# It seems a little deviated from normal distrubution. One way to get this correct is to take the log of this variable.

# %%
train_data['SalePrice']=np.log(train_data['SalePrice'])
encoded_train_data['SalePrice']=np.log(encoded_train_data['SalePrice'])

# %%
sns.distplot(train_data['SalePrice']);
print ('average sale price: '+str(train_data['SalePrice'].mean()))
# Out:
# average sale price: 12.024050901109373

# %% [markdown]
# We can see that it is rougly converted to normal distribution.

# %% [markdown]
# One important variable is 'GrLivArea'. It represents the area of the house.

# %%
plt.scatter(train_data['GrLivArea'],train_data['SalePrice'],alpha=0.7);
plt.xlabel('Living Area');
plt.ylabel('Sale Price');
plt.yscale('log')

# %% [markdown]
# It is seems reasonable to remove points with Living area greater than 4000 sqft.

# %%
train_data=train_data[train_data['GrLivArea']<4000]
encoded_train_data=encoded_train_data[encoded_train_data['GrLivArea']<4000]

# %%
#This bboxplot shows the Sale price vs overall condition
sns.boxplot(x='OverallCond',y='SalePrice',data=train_data);
plt.xlabel('Overall condition(1-10)');
plt.ylabel('Sale Price');

# %%
plt.scatter(train_data['LotFrontage'],train_data['SalePrice'],alpha=0.3,color='red');
plt.xlabel('street length');
plt.ylabel('Sale Price');

# %%
encoded_train_data.corr()['SalePrice'].sort_values()
# Out:
# ExterQual       -0.584137
# BsmtQual        -0.574915
# KitchenQual     -0.530470
# GarageType      -0.504519
# HeatingQC       -0.425864
# GarageFinish    -0.414553
# BsmtExposure    -0.299405
# LotShape        -0.273934
# MSZoning        -0.190488
# EnclosedPorch   -0.148636
# KitchenAbvGr    -0.147890
# Heating         -0.140651
# BsmtFinType1    -0.123903
# MSSubClass      -0.075083
# BldgType        -0.071098
# MiscFeature     -0.070772
# LotConfig       -0.064371
# FireplaceQu     -0.053667
# PoolQC          -0.038768
# SaleType        -0.038664
# LowQualFinSF    -0.037698
# OverallCond     -0.036843
# YrSold          -0.034319
# MiscVal         -0.019752
# BsmtHalfBath    -0.014974
# MasVnrType      -0.013965
# Utilities       -0.012618
# Condition2       0.000109
# BsmtFinSF2       0.006420
# LandContour      0.031806
#                    ...
# BsmtUnfSF        0.223248
# BsmtFullBath     0.238851
# LotArea          0.258945
# SaleCondition    0.260785
# GarageQual       0.276777
# Electrical       0.298760
# PavedDrive       0.306194
# 2ndFlrSF         0.306605
# HalfBath         0.311191
# GarageCond       0.325360
# OpenPorchSF      0.327038
# WoodDeckSF       0.330573
# LotFrontage      0.342997
# GarageYrBlt      0.351023
# CentralAir       0.353708
# BsmtFinSF1       0.382710
# Foundation       0.412103
# MasVnrArea       0.425946
# Fireplaces       0.487126
# TotRmsAbvGrd     0.533446
# YearRemodAdd     0.568986
# YearBuilt        0.588977
# FullBath         0.590919
# 1stFlrSF         0.613742
# TotalBsmtSF      0.641553
# GarageArea       0.655211
# GarageCars       0.680408
# GrLivArea        0.718844
# OverallQual      0.819240
# SalePrice        1.000000
# Name: SalePrice, Length: 80, dtype: float64

# %%
sns.barplot(x='OverallQual', y='SalePrice', hue=None, data=train_data);
plt.yscale('log')

# %% [markdown]
# We can see that Overall quality is an important deciding factor for sale price.

# %%
plt.scatter(train_data['YearBuilt'],train_data['SalePrice'],alpha=0.3);
plt.xlabel('Year the house was bulit');
plt.ylabel('Sale Price');

# %% [markdown]
# A general trend can be seen that new houses have more prices.

# %%
sns.boxplot(x='ExterQual', y='SalePrice', hue=None, data=train_data);

# %% [markdown]
# It can be seen that fair houses have less price than excellent ones.

# %% [markdown]
# ## Model fitting

# %%
#independent variables are other than the predicted variable
independent_variables=[x for x in train_data.columns if x not in ['SalePrice']]

# %%
#used to do the train tes split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(encoded_train_data[independent_variables], encoded_train_data['SalePrice'], test_size=0.2, random_state = 7)

# %%
# for doing cross validation and getting the cross validation score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
# this scorer function evaluates the mean squared error
def scorer(estimator,X,y):
    y1=np.array(estimator.predict(X))
    mse= np.mean((y-y1)**2)
    return mse

# %%
a=cross_val_score(lm,X_train,Y_train,scoring=scorer,cv=5)
print('5-fold cross validation score: '+ str(a.mean()))
# Out:
# 5-fold cross validation score: 0.0150849782974

# %% [markdown]
# Let's see how well our model did on test data

# %%
lm.fit(X_train,Y_train)
print('test score: '+ str(scorer(lm,X_test,Y_test)))
print('the r-squared score: '+str(lm.score(X_test,Y_test)))
# Out:
# test score: 0.0214571316953419
# the r-squared score: 0.864131181212

# %%
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.3)
plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40,alpha=0.9)
plt.hlines(y = 0, xmin=10, xmax = 14)
plt.title('Residual Plot using training (blue) and test (green) data')
plt.ylabel('Residuals')

# %% [markdown]
# ### Ridge regression

# %%
from sklearn.linear_model import Ridge

# %%
alphas=[0.001,0.01,0.1,1,10,1000]
scores=[]
for alpha in alphas:
    rm=Ridge(alpha=alpha,normalize=True)
    scores.append(float('%0.4f'%(cross_val_score(rm,X_train,Y_train,scoring=scorer,cv=5).mean())))
    
print("Scores obtained: ")
print(scores)
min_score=min(scores)
print('\n')
print('Minimum score is '+str(min_score)+' at alpha='+str(alphas[scores.index(min_score)]))
# Out:
# Scores obtained:
# [0.0151, 0.015, 0.0149, 0.0178, 0.0556, 0.1546]
#
#
# Minimum score is 0.0149 at alpha=0.1

# %%
rm=Ridge(alpha=0.1)
rm.fit(X_train,Y_train)
print('alpha=0.1 :')
print('test score: '+ str(scorer(rm,X_test,Y_test)))
print('the r-squared score: '+str(rm.score(X_test,Y_test)))
# Out:
# alpha=0.1 :
# test score: 0.02147507475807568
# the r-squared score: 0.864017563848

# %%
rm=Ridge(alpha=0.01)
rm.fit(X_train,Y_train)
print('alpha=0.01 :')
print('test score: '+ str(scorer(rm,X_test,Y_test)))
print('the r-squared score: '+str(rm.score(X_test,Y_test)))
# Out:
# alpha=0.01 :
# test score: 0.02145897867855956
# the r-squared score: 0.864119485919

# %% [markdown]
# ### Lasso regression

# %%
from sklearn.linear_model import Lasso

# %%
alphas=[0.001,0.01,0.1,1,10,1000]
scores=[]
for alpha in alphas:
    lam=Lasso(alpha=alpha,normalize=True)
    scores.append(float('%0.4f'%(cross_val_score(lam,X_train,Y_train,scoring=scorer,cv=5).mean())))
    
print("Scores obtained: ")
print(scores)
min_score=min(scores)
print('\n')
print('Minimum score is '+str(min_score)+' at alpha='+str(alphas[scores.index(min_score)]))
# Out:
# Scores obtained:
# [0.0211, 0.1447, 0.1572, 0.1572, 0.1572, 0.1572]
#
#
# Minimum score is 0.0211 at alpha=0.001

# %%
lam=Lasso(alpha=0.001)
lam.fit(X_train,Y_train)
print('alpha=0.001 :')
print('test score: '+ str(scorer(lam,X_test,Y_test)))
print('the r-squared score: '+str(lam.score(X_test,Y_test)))
# Out:
# alpha=0.001 :
# test score: 0.02029933860645992
# the r-squared score: 0.871462449045

# %%
lam=Lasso(alpha=0.0001)
lam.fit(X_train,Y_train)
print('alpha=0.0001 :')
print('test score: '+ str(scorer(lam,X_test,Y_test)))
print('the r-squared score: '+str(lam.score(X_test,Y_test)))
# Out:
# alpha=0.0001 :
# test score: 0.02108101214493405
# the r-squared score: 0.866512809836

# %% [markdown]
# ### Decision tree regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
depths=[3,5,6,7,9]
scores=[]
for depth in depths:
    dm=DecisionTreeRegressor(max_depth=depth,max_features='sqrt',random_state=1)
    scores.append(float('%0.4f'%(cross_val_score(dm,X_train,Y_train,scoring=scorer,cv=5).mean())))
    
print("Scores obtained: ")
print(scores)
min_score=min(scores)
print('\n')
print('Minimum score is '+str(min_score)+' at max_depth='+str(depths[scores.index(min_score)]))
# Out:
# Scores obtained:
# [0.0787, 0.0571, 0.0497, 0.0483, 0.0508]
#
#
# Minimum score is 0.0483 at max_depth=7

# %%
dm=DecisionTreeRegressor(max_depth=7)
dm.fit(X_train,Y_train)
print('max-depth=7 :')
print('test score: '+ str(scorer(dm,X_test,Y_test)))
print('the r-squared score: '+str(dm.score(X_test,Y_test)))
# Out:
# max-depth=7 :
# test score: 0.0377032282308035
# the r-squared score: 0.761259186132

# %%
sns.set(font_scale=0.9)
importances=dm.feature_importances_
std = np.std([dm.feature_importances_],
             axis=0)
indices = np.argsort(importances)[::-1]
sorted_important_features=[]
predictors=X_train.columns
for i in indices:
    sorted_important_features.append(predictors[i])

plt.figure()
plt.title("Feature Importances By Random Forest Model")
plt.bar(range(np.size(predictors)), importances[indices],
        yerr=std[indices], align="center")
plt.xticks(range(np.size(predictors)), sorted_important_features, rotation='vertical')

plt.xlim([-1, np.size(predictors)]);

# %%
#sns.set?

# %% [markdown]
# ### Adaptive boosting

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
adam=AdaBoostRegressor(lam,n_estimators=20,learning_rate=0.01,random_state=1)

# %%
a=cross_val_score(adam,X_train,Y_train,scoring=scorer,cv=5)
print('5-fold cross validation score: '+ str(a.mean()))
# Out:
# 5-fold cross validation score: 0.0151493812824

# %%
adam.fit(X_train,Y_train)
print('test score: '+ str(scorer(adam,X_test,Y_test)))
print('the r-squared score: '+str(adam.score(X_test,Y_test)))
# Out:
# test score: 0.0195557098543117
# the r-squared score: 0.876171184658

# %% [markdown]
# ## Predictions on test data

# %%
test_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RH         80.0    11622   Pave   NaN      Reg
# 1          20       RL         81.0    14267   Pave   NaN      IR1
# 2          60       RL         74.0    13830   Pave   NaN      IR1
# 3          60       RL         78.0     9978   Pave   NaN      IR1
# 4         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...               120        0    NaN
# 1         Lvl    AllPub    Corner      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Inside      ...                 0        0    NaN
# 4         HLS    AllPub    Inside      ...               144        0    NaN
#
#    Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0  MnPrv         NaN       0       6    2010        WD         Normal
# 1    NaN        Gar2   12500       6    2010        WD         Normal
# 2  MnPrv         NaN       0       3    2010        WD         Normal
# 3    NaN         NaN       0       6    2010        WD         Normal
# 4    NaN         NaN       0       1    2010        WD         Normal
#
# [5 rows x 79 columns]

# %%
test_data.shape
# Out:
# (1459, 79)

# %%
null_columns_test=test_data.columns[test_data.isnull().any()]
null_columns_test
# Out:
# Index(['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea',
#        'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType'],
#       dtype='object')

# %%
null_categorical_test=[x for x in categorical_variables if x in null_columns_test]
null_categorical_test
# Out:
# ['MSZoning',
#  'Alley',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType']

# %%
#variables which are not in null_columns but in categorical missing variables of test data.
null_columns_1=[x for x in null_categorical_test if x not in null_columns]
null_columns_1
# Out:
# ['MSZoning',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'KitchenQual',
#  'Functional',
#  'SaleType']

# %%
null_columns_2=[x for x in null_categorical_test if x not in null_columns_1]
null_columns_2
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
def mode_f(s):
    #train_data[categorical_variables].apply(lambda x: len(x.unique()))
    columns=s.columns

# %%
for i in null_columns_1:
    #mode=str(test_data[i].mode())
    #test_data[i]=test_data[i].fillna(value=mode)
    print(repr(test_data[i].mode()))
# Out:
# 0    RL
# dtype: object
# 0    AllPub
# dtype: object
# 0    VinylSd
# dtype: object
# 0    VinylSd
# dtype: object
# 0    TA
# dtype: object
# 0    Typ
# dtype: object
# 0    WD
# dtype: object

# %%
type(test_data['MSZoning'][3])
# Out:
# str

# %%
type(mode)
# Out:
# str

# %%
(mode)
# Out:
# '0    WD\ndtype: object'

# %%
print(test_data[null_columns_1].isnull().sum())
# Out:
# MSZoning       0
# Utilities      0
# Exterior1st    0
# Exterior2nd    0
# KitchenQual    0
# Functional     0
# SaleType       0
# dtype: int64

# %%
test_data[null_columns_2]=test_data[null_columns_2].fillna('None')

# %%
null_noncategorical_test=[x for x in null_columns_test if x not in null_categorical_test]
null_noncategorical_test
# Out:
# ['LotFrontage',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea']

# %%
encoded_test_data=pd.DataFrame(data=test_data,copy=True)

# %%
encoded_test_data[categorical_variables] =encoded_test_data[categorical_variables].apply(lambda x: d[x.name].transform(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-dd9434baab75> in <module>()
# ----> 1 encoded_test_data[categorical_variables] =encoded_test_data[categorical_variables].apply(lambda x: d[x.name].transform(x))
#
# C:\Users\user\Anaconda2\envs\py35\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4358                         f, axis,
#    4359                         reduce=reduce,
# -> 4360                         ignore_failures=ignore_failures)
#    4361             else:
#    4362                 return self._apply_broadcast(f, axis)
#
# C:\Users\user\Anaconda2\envs\py35\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4454             try:
#    4455                 for i, v in enumerate(series_gen):
# -> 4456                     results[i] = func(v)
#    4457                     keys.append(v.name)
#    4458             except Exception as e:
#
# <ipython-input-80-dd9434baab75> in <lambda>(x)
# ----> 1 encoded_test_data[categorical_variables] =encoded_test_data[categorical_variables].apply(lambda x: d[x.name].transform(x))
#
# C:\Users\user\Anaconda2\envs\py35\lib\site-packages\sklearn\preprocessing\label.py in transform(self, y)
#     151         if len(np.intersect1d(classes, self.classes_)) < len(classes):
#     152             diff = np.setdiff1d(classes, self.classes_)
# --> 153             raise ValueError("y contains new labels: %s" % str(diff))
#     154         return np.searchsorted(self.classes_, y)
#     155
#
# ValueError: ("y contains new labels: ['0    RL\\ndtype: object']", 'occurred at index MSZoning')

# %%
encoded_test_data
# Out:
#       MSSubClass                MSZoning  LotFrontage  LotArea Street Alley  \
# 0             20                      RH         80.0    11622   Pave  None
# 1             20                      RL         81.0    14267   Pave  None
# 2             60                      RL         74.0    13830   Pave  None
# 3             60                      RL         78.0     9978   Pave  None
# 4            120                      RL         43.0     5005   Pave  None
# 5             60                      RL         75.0    10000   Pave  None
# 6             20                      RL          NaN     7980   Pave  None
# 7             60                      RL         63.0     8402   Pave  None
# 8             20                      RL         85.0    10176   Pave  None
# 9             20                      RL         70.0     8400   Pave  None
# 10           120                      RH         26.0     5858   Pave  None
# 11           160                      RM         21.0     1680   Pave  None
# 12           160                      RM         21.0     1680   Pave  None
# 13           160                      RL         24.0     2280   Pave  None
# 14           120                      RL         24.0     2280   Pave  None
# 15            60                      RL        102.0    12858   Pave  None
# 16            20                      RL         94.0    12883   Pave  None
# 17            20                      RL         90.0    11520   Pave  None
# 18            20                      RL         79.0    14122   Pave  None
# 19            20                      RL        110.0    14300   Pave  None
# 20            60                      RL        105.0    13650   Pave  None
# 21           120                      RL         41.0     7132   Pave  None
# 22            20                      RL        100.0    18494   Pave  None
# 23           120                      RL         43.0     3203   Pave  None
# 24            80                      RL         67.0    13300   Pave  None
# 25            60                      RL         63.0     8577   Pave  None
# 26            60                      RL         60.0    17433   Pave  None
# 27            20                      RL         73.0     8987   Pave  None
# 28            20                      FV         92.0     9215   Pave  None
# 29            20                      FV         84.0    10440   Pave  None
# ...          ...                     ...          ...      ...    ...   ...
# 1429          30                      RM         50.0     7030   Pave  None
# 1430          50                      RM         75.0     9060   Pave  None
# 1431          30                 C (all)         69.0    12366   Pave  None
# 1432         190                 C (all)         50.0     9000   Pave  None
# 1433          50                 C (all)         60.0     8520   Grvl  None
# 1434         120                      RM         41.0     5748   Pave  None
# 1435         120                      RM         44.0     3842   Pave  None
# 1436          20                      RL         69.0    23580   Pave  None
# 1437          90                      RL         65.0     8385   Pave  None
# 1438          20                      RL         70.0     9116   Pave  None
# 1439          80                      RL        140.0    11080   Pave  None
# 1440          20                      RL          NaN    50102   Pave  None
# 1441          20                      RL          NaN     8098   Pave  None
# 1442          20                      RL         95.0    13618   Pave  None
# 1443          20                      RL         88.0    11577   Pave  None
# 1444          20  0    RL\ndtype: object        125.0    31250   Pave  None
# 1445          90                      RM         78.0     7020   Pave  None
# 1446         160                      RM         41.0     2665   Pave  None
# 1447          20                      RL         58.0    10172   Pave  None
# 1448          90                      RL          NaN    11836   Pave  None
# 1449         180                      RM         21.0     1470   Pave  None
# 1450         160                      RM         21.0     1484   Pave  None
# 1451          20                      RL         80.0    13384   Pave  None
# 1452         160                      RM         21.0     1533   Pave  None
# 1453         160                      RM         21.0     1526   Pave  None
# 1454         160                      RM         21.0     1936   Pave  None
# 1455         160                      RM         21.0     1894   Pave  None
# 1456          20                      RL        160.0    20000   Pave  None
# 1457          85                      RL         62.0    10441   Pave  None
# 1458          60                      RL         74.0     9627   Pave  None
#
#      LotShape LandContour Utilities LotConfig      ...       ScreenPorch  \
# 0         Reg         Lvl    AllPub    Inside      ...               120
# 1         IR1         Lvl    AllPub    Corner      ...                 0
# 2         IR1         Lvl    AllPub    Inside      ...                 0
# 3         IR1         Lvl    AllPub    Inside      ...                 0
# 4         IR1         HLS    AllPub    Inside      ...               144
# 5         IR1         Lvl    AllPub    Corner      ...                 0
# 6         IR1         Lvl    AllPub    Inside      ...                 0
# 7         IR1         Lvl    AllPub    Inside      ...                 0
# 8         Reg         Lvl    AllPub    Inside      ...                 0
# 9         Reg         Lvl    AllPub    Corner      ...                 0
# 10        IR1         Lvl    AllPub       FR2      ...                 0
# 11        Reg         Lvl    AllPub    Inside      ...                 0
# 12        Reg         Lvl    AllPub    Inside      ...                 0
# 13        Reg         Lvl    AllPub       FR2      ...                 0
# 14        Reg         Lvl    AllPub       FR2      ...                 0
# 15        IR1         Lvl    AllPub    Inside      ...                 0
# 16        IR1         Lvl    AllPub    Corner      ...                 0
# 17        Reg         Lvl    AllPub    Inside      ...                 0
# 18        IR1         Lvl    AllPub    Inside      ...                 0
# 19        Reg         HLS    AllPub    Inside      ...                 0
# 20        Reg         Lvl    AllPub    Corner      ...                 0
# 21        IR1         Lvl    AllPub    Inside      ...                 0
# 22        IR1         Lvl    AllPub    Corner      ...                 0
# 23        Reg         Lvl    AllPub    Inside      ...                 0
# 24        IR1         Lvl    AllPub    Inside      ...                 0
# 25        IR1         Lvl    AllPub    Inside      ...                 0
# 26        IR2         Lvl    AllPub   CulDSac      ...               256
# 27        Reg         Lvl    AllPub    Inside      ...                 0
# 28        Reg         Lvl    AllPub    Inside      ...                 0
# 29        Reg         Lvl    AllPub    Corner      ...               216
# ...       ...         ...       ...       ...      ...               ...
# 1429      Reg         Lvl    AllPub    Inside      ...                 0
# 1430      Reg         Lvl    AllPub    Inside      ...                 0
# 1431      Reg         Lvl    AllPub    Inside      ...                 0
# 1432      Reg         Lvl    AllPub    Inside      ...                 0
# 1433      Reg         Bnk    AllPub    Inside      ...                 0
# 1434      IR1         HLS    AllPub    Inside      ...               153
# 1435      IR1         HLS    AllPub    Inside      ...               155
# 1436      IR1         Lvl    AllPub    Inside      ...                 0
# 1437      Reg         Lvl    AllPub    Inside      ...                 0
# 1438      Reg         Lvl    AllPub    Corner      ...                 0
# 1439      Reg         Lvl    AllPub    Corner      ...                 0
# 1440      IR1         Low    AllPub    Inside      ...               138
# 1441      IR1         Lvl    AllPub    Inside      ...                 0
# 1442      Reg         Lvl    AllPub    Corner      ...                 0
# 1443      Reg         Lvl    AllPub    Inside      ...                 0
# 1444      Reg         Lvl    AllPub    Inside      ...                 0
# 1445      Reg         Lvl    AllPub    Inside      ...                 0
# 1446      Reg         Lvl    AllPub    Inside      ...                 0
# 1447      IR1         Lvl    AllPub    Inside      ...                 0
# 1448      IR1         Lvl    AllPub    Corner      ...                 0
# 1449      Reg         Lvl    AllPub    Inside      ...                 0
# 1450      Reg         Lvl    AllPub    Inside      ...                 0
# 1451      Reg         Lvl    AllPub    Inside      ...                 0
# 1452      Reg         Lvl    AllPub    Inside      ...                 0
# 1453      Reg         Lvl    AllPub    Inside      ...                 0
# 1454      Reg         Lvl    AllPub    Inside      ...                 0
# 1455      Reg         Lvl    AllPub    Inside      ...                 0
# 1456      Reg         Lvl    AllPub    Inside      ...                 0
# 1457      Reg         Lvl    AllPub    Inside      ...                 0
# 1458      Reg         Lvl    AllPub    Inside      ...                 0
#
#      PoolArea PoolQC  Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  \
# 0           0   None  MnPrv        None       0       6    2010        WD
# 1           0   None   None        Gar2   12500       6    2010        WD
# 2           0   None  MnPrv        None       0       3    2010        WD
# 3           0   None   None        None       0       6    2010        WD
# 4           0   None   None        None       0       1    2010        WD
# 5           0   None   None        None       0       4    2010        WD
# 6           0   None  GdPrv        Shed     500       3    2010        WD
# 7           0   None   None        None       0       5    2010        WD
# 8           0   None   None        None       0       2    2010        WD
# 9           0   None  MnPrv        None       0       4    2010        WD
# 10          0   None   None        None       0       6    2010        WD
# 11          0   None   None        None       0       2    2010       COD
# 12          0   None   None        None       0       3    2010        WD
# 13          0   None   None        None       0       6    2010        WD
# 14          0   None   None        None       0       6    2010        WD
# 15          0   None   None        None       0       1    2010       New
# 16          0   None   None        None       0       6    2010       New
# 17          0   None   None        None       0       6    2010        WD
# 18          0   None   None        None       0       2    2010        WD
# 19          0   None   None        None       0       6    2010        WD
# 20          0   None   None        None       0       6    2010        WD
# 21          0   None   None        None       0       4    2010        WD
# 22          0   None   None        None       0       1    2010        WD
# 23          0   None   None        None       0       1    2010        WD
# 24          0   None   None        None       0       6    2010        WD
# 25          0   None   None        None       0       4    2010        WD
# 26          0   None   None        None       0       1    2010        WD
# 27          0   None   None        None       0       5    2010        WD
# 28          0   None   None        None       0       4    2010       New
# 29          0   None   None        None       0       5    2010        WD
# ...       ...    ...    ...         ...     ...     ...     ...       ...
# 1429        0   None  MnPrv        None       0       3    2006        WD
# 1430        0   None   None        None       0       4    2006        WD
# 1431        0   None   None        None       0      10    2006        WD
# 1432        0   None   None        None       0      10    2006        WD
# 1433        0   None   None        None       0       4    2006        WD
# 1434        0   None   None        None       0       2    2006       New
# 1435        0   None   None        None       0      12    2006        WD
# 1436        0   None   None        None       0       9    2006        WD
# 1437        0   None   None        None       0      10    2006        WD
# 1438        0   None   None        None       0       5    2006        WD
# 1439        0   None   None        None       0       5    2006        WD
# 1440        0   None   None        None       0       3    2006        WD
# 1441        0   None   None        None       0      10    2006        WD
# 1442        0   None   None        None       0      11    2006       New
# 1443        0   None   None        None       0       9    2006       New
# 1444        0   None   None        None       0       5    2006        WD
# 1445        0   None   None        None       0      11    2006        WD
# 1446        0   None   None        None       0       5    2006        WD
# 1447        0   None   None        None       0      10    2006        WD
# 1448        0   None   None        None       0       3    2006        WD
# 1449        0   None   None        None       0       4    2006        WD
# 1450        0   None   None        None       0       5    2006        WD
# 1451        0   None   None        None       0       5    2006        WD
# 1452        0   None   None        None       0      12    2006        WD
# 1453        0   None  GdPrv        None       0       6    2006        WD
# 1454        0   None   None        None       0       6    2006        WD
# 1455        0   None   None        None       0       4    2006        WD
# 1456        0   None   None        None       0       9    2006        WD
# 1457        0   None  MnPrv        Shed     700       7    2006        WD
# 1458        0   None   None        None       0      11    2006        WD
#
#       SaleCondition
# 0            Normal
# 1            Normal
# 2            Normal
# 3            Normal
# 4            Normal
# 5            Normal
# 6            Normal
# 7            Normal
# 8            Normal
# 9            Normal
# 10           Normal
# 11           Normal
# 12           Normal
# 13           Normal
# 14           Normal
# 15          Partial
# 16          Partial
# 17           Normal
# 18           Normal
# 19           Normal
# 20           Normal
# 21           Normal
# 22           Normal
# 23           Normal
# 24           Normal
# 25           Normal
# 26           Normal
# 27           Normal
# 28          Partial
# 29           Normal
# ...             ...
# 1429         Normal
# 1430         Normal
# 1431        Abnorml
# 1432        Abnorml
# 1433         Normal
# 1434        Partial
# 1435         Normal
# 1436         Normal
# 1437         Normal
# 1438         Normal
# 1439         Normal
# 1440         Alloca
# 1441         Normal
# 1442        Partial
# 1443        Partial
# 1444         Normal
# 1445         Normal
# 1446         Normal
# 1447         Normal
# 1448         Normal
# 1449         Normal
# 1450         Normal
# 1451         Normal
# 1452        Abnorml
# 1453         Normal
# 1454         Normal
# 1455        Abnorml
# 1456        Abnorml
# 1457         Normal
# 1458         Normal
#
# [1459 rows x 79 columns]
